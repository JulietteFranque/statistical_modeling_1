# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc
rc('text', usetex=True)
plt.style.use('ggplot')
plt.rcParams.update({'axes.labelsize':16})
plt.rcParams.update({'axes.titlesize':16})
plt.rcParams.update({'legend.fontsize':16})
plt.rcParams['xtick.labelsize'] = 16
plt.rcParams['ytick.labelsize'] = 16
plt.rcParams['lines.linewidth'] = 4
import pandas as pd
from scipy.stats import norm
import pymc as pm
from scipy.linalg import block_diag
import copy

# %%
dates = pd.date_range(start='1/1/2013', end='6/1/2014')
cov_1 = np.sin(2*np.pi/90 * days) + 10
cov_2 = np.sin(2*np.pi/360 * days) + 10
covs = np.vstack([cov_1, cov_2])

# %%
def make_block(A, B):
    mat = np.block([[A, np.zeros([A.shape[0], B.shape[1]])], [np.zeros([B.shape[0], A.shape[1]]), B]])
    return mat

# %%
# local linear trend
Z_1 = np.ones(len(dates)).reshape(1, -1)
T_1 = np.ones(1).reshape(-1, 1)
R_1 = np.eye(1).reshape(-1, 1)
eta_1 = norm(0, .1).rvs(size=(1, len(dates)-1))

# dynamic regression
Z_2 = covs
T_2 = np.eye(covs.shape[0])
R_2 = np.eye(covs.shape[0])
eta_2 = norm(0, .01).rvs(size=(2, len(dates)-1))

# combine arrays
Z = np.vstack([Z_1 , Z_2[0, :], Z_2[1, :]])
T = make_block(T_1, T_2)
R = make_block(R_1, R_2)
eta = np.vstack([eta_1, eta_2])

# %%
alpha = np.zeros((3, len(dates)))
alpha[:, 0] = [0, 1, 1]
for i in range(len(dates)-1):
    alpha[:, i+1] = alpha[:, i]@T  +  norm(0, .1).rvs() + R@eta[:, 0]

# %%
y = (Z * alpha).sum(axis=0) + norm(0, .1).rvs(len(dates))
y_observed = copy.copy(y)

# %%
idx = int(np.where(dates ==  '2014-01-01')[0])
uplift = .2
y_observed[idx:] = y_observed[idx:] * (1 + uplift)

# %%
plt.figure(figsize=(12, 5))
plt.plot(dates, y, label='no intervention')
plt.plot(dates, y_observed, label='observed (intervention)')
plt.xticks(rotation=45)
plt.legend();

# %%
def draw_betas(betas, idx, sig):
    betas[idx+1] = norm(betas[idx], sig).rvs()
    return betas

def draw_mus(mus, idx, sig):
    mus[idx+1] = norm(mus[idx], sig).rvs()
    return mus
    
def make_betas_vector(n, sig=.01):
    betas = np.ones(n)
    for idx in range(n-1):
        betas = draw_betas(betas, idx, sig)
    return betas

def make_mus_vector(n, sig=.1):
    mus = np.zeros(n)
    for idx in range(n-1):
        mus = draw_mus(mus, idx, sig)
    return mus

# %%
days = np.arange(0, len(dates), 1)

beta_1 = make_betas_vector(len(dates))
beta_2 = make_betas_vector(len(dates))
mus = make_mus_vector(len(dates))
eps = norm(0, .1).rvs(len(dates))
uplift = .2
data = beta_1*cov_1 + beta_2*cov_2 + mus + eps
plt.figure(figsize=(10, 5))
plt.plot(dates, data)


plt.xticks(rotation=45)
plt.plot(dates, data)
plt.plot(dates, cov_1)
plt.plot(dates, cov_2)

# %%
with pm.Model() as model:
    sig_1 = np.sqrt(pm.InverseGamma('sig1', 0.5, 0.5))
    sig_2 = np.sqrt(pm.InverseGamma('sig2', 0.5, 0.5))                
    sig_mu = np.sqrt(pm.InverseGamma('sig_mu', 0.5, 0.5))
    betas_1 = make_betas_vector(idx, sig_1.eval())
    betas_2 = make_betas_vector(idx, sig_2.eval())
    mus =  make_mus_vector(idx, sig_mu.eval())
    eps = np.sqrt(pm.InverseGamma('sigma', 0.5, 0.5))
    like = pm.Normal('like', betas_1 * cov_1[:idx] + betas_2 * cov_2[:idx] + mus, eps, observed=data[:idx])
    traces = pm.sample(return_inferencedata=None, target_accept=.99, chains=1)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [sig1, sig2, sig_mu, sigma]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:07<00:00 Sampling chain 0, 0 divergences]
#     </div>
# Sampling 1 chain for 1_000 tune and 1_000 draw iterations (1_000 + 1_000 draws total) took 8 seconds.

# %%
betas_1
# Out:
# array([ 1.        ,  2.2212222 ,  1.52507891,  1.53170323,  1.55004563,
#         2.4119678 ,  3.75377864,  3.35684428,  2.34900485,  2.78444266,
#         2.61214533,  2.41823559,  2.28514533,  2.10682589,  2.20061773,
#         2.29020146,  2.28979486,  1.46402196,  0.563329  ,  1.55152075,
#         1.48634864,  1.1489451 ,  1.44808167,  1.59442491,  0.27996461,
#         1.95793109,  2.44673489,  3.74469056,  4.83350804,  6.3179777 ,
#         5.64060246,  4.38770087,  4.78163334,  4.19844043,  4.56511943,
#         4.77741127,  5.58001738,  5.47685237,  6.28396746,  6.40708959,
#         5.3435623 ,  6.38357387,  5.57581692,  6.47158603,  6.40014709,
#         6.15282506,  5.72049101,  5.16985533,  5.49270808,  4.21077288,
#         4.26117946,  3.34107005,  3.43072276,  1.71966841,  1.745941  ,
#         2.30071037,  0.78267231,  0.73831564,  2.25389932,  1.6860256 ,
#         3.71716753,  3.99001243,  3.3605783 ,  3.01991277,  1.68813476,
#         0.29864761,  0.60110769,  0.34367229,  1.08810108,  1.15921543,
#         2.46038192,  2.38740361,  2.60852293,  2.14583201,  2.78424759,
#         2.7339746 ,  4.35649785,  4.57433123,  4.42529549,  4.64200833,
#         5.03988731,  6.43472777,  6.40770238,  5.12296808,  5.04248487,
#         5.8922022 ,  4.94125649,  5.02952647,  6.22722781,  4.85402244,
#         3.55018484,  2.84905642,  2.26333423,  2.56570728,  2.15257352,
#         2.73478354,  1.65102001,  1.31480033,  2.30252973,  1.55832488,
#         1.68265429,  0.73413304, -0.40952497, -1.08022149, -1.04943684,
#         0.17047387,  0.30159023,  1.54358909,  0.47873304,  0.78555094,
#         0.71384676,  0.80990868,  2.31374494,  2.53029936,  4.2727823 ,
#         3.79221653,  4.78852978,  4.69019975,  4.69523889,  3.3569215 ,
#         4.06774776,  4.43327833,  5.43080122,  4.02487035,  4.63391754,
#         5.69919856,  4.78128182,  6.03482277,  5.84666154,  3.7099908 ,
#         4.60012526,  5.3619185 ,  5.35516003,  4.85014868,  5.62670658,
#         6.3148857 ,  9.8662914 , 10.02349174, 10.32023787, 11.51111934,
#        10.71603664,  8.92235014,  9.39176608,  9.96057223,  9.01576152,
#         8.51964776,  8.80786135,  8.78887497,  8.46133705,  6.86611036,
#         7.56888583,  6.81444347,  7.6492573 ,  7.65233219,  6.51232857,
#         6.31998819,  7.10494415,  6.8696098 ,  7.09541968,  5.49752383,
#         6.21914603,  6.28287164,  6.54479023,  6.23321047,  7.75898403,
#         7.75943806,  7.20410182,  7.61649617,  7.13496751,  7.73115737,
#         6.9840277 ,  6.62145018,  6.6425163 ,  6.49404154,  5.56358001,
#         4.80387019,  4.00736032,  3.5165714 ,  4.1662618 ,  4.25232803,
#         2.93060395,  2.12872519,  1.9362844 ,  3.43009008,  1.89394968,
#         1.72254719,  0.34449347,  0.01417571,  0.3142955 , -0.58610826,
#        -0.11292931, -0.24269898, -0.05230075,  0.80483161,  0.97444558,
#         0.55083992,  1.38725987,  1.62558073,  2.59544502,  2.46050978,
#         2.34477944,  2.46091857,  3.93173558,  4.25779894,  4.05299048,
#         4.28710364,  4.40233179,  3.56921106,  2.34503954,  0.86723344,
#        -0.19180885, -0.75972737,  0.68158877, -0.85353383,  0.16582162,
#         1.42804674,  1.02658429, -0.29099942, -0.8424728 ,  0.32421706,
#        -0.26492233, -1.02462014, -0.98411448, -0.23278047, -0.32530211,
#        -0.86380093, -0.90538809, -0.40025588, -0.71022579, -0.42690359,
#        -0.02073576,  0.62244711,  0.18826574, -0.9660214 ,  0.37456627,
#        -0.15178016, -0.58498647, -1.33136877, -1.243842  , -0.95153288,
#        -1.58734583, -1.2133862 , -0.96185621, -2.14105113, -2.23029131,
#        -3.20667558, -4.52716523, -4.48951169, -6.28087057, -5.30999826,
#        -5.31256781, -4.77293841, -3.66056988, -4.03493797, -3.86446349,
#        -3.32394658, -3.94363516, -3.78780883, -2.82643301, -2.91228557,
#        -1.46834816, -0.59446792, -0.23632732,  1.27527059,  1.25197825,
#        -0.03863459, -0.03449972, -0.61120242, -0.67242946, -0.3231716 ,
#         0.45539205,  1.72535808,  2.3663505 ,  2.42425716,  1.50182771,
#         2.64622645,  1.64973135, -0.14819664,  0.14691432,  0.54536842,
#        -0.5917836 , -1.51423337, -0.76435647,  0.15326843,  0.43369324,
#        -1.2226766 , -2.1774465 , -3.1135139 , -2.49495882, -1.79389838,
#        -2.28187066, -1.76689026, -2.05919775, -2.05536458, -2.25146298,
#        -2.25287519, -2.23697063, -2.26694565, -1.45230929, -1.66596908,
#        -0.94530635, -1.01142016, -2.11454861, -3.11468695, -5.29586655,
#        -5.69340508, -6.89193744, -5.75598162, -6.9295226 , -7.56543562,
#        -7.99416378, -7.90224706, -8.10679597, -6.90357845, -7.53946349,
#        -6.77205057, -7.18043819, -6.87845481, -6.54848893, -6.70466109,
#        -7.67301786, -8.01982319, -8.67212715, -7.30642405, -6.92504072,
#        -6.29584414, -4.82783076, -5.72591891, -5.59924156, -4.69578457,
#        -4.30882132, -4.66565816, -5.48124653, -5.97009204, -6.19447303,
#        -6.19817201, -5.61184967, -5.75053995, -5.88936924, -6.87141214,
#        -6.19638058, -6.9025534 , -6.96841287, -8.50531507, -8.89806768,
#        -9.6023001 , -9.56571781, -7.73641399, -7.41911074, -6.69212732,
#        -6.62722715, -5.93223005, -5.82279438, -5.49031209, -6.90538505,
#        -6.65232331, -8.03341607, -8.18358816, -6.71771504, -8.03727391,
#        -7.69059502, -6.63561012, -7.20470194, -7.63446364, -8.48945833,
#        -9.40242252])

# %%
traces['like']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [157], in <cell line: 1>()
# ----> 1 traces['like']
#
# File ~/opt/anaconda3/envs/pymc_env/lib/python3.10/site-packages/pymc/backends/base.py:358, in MultiTrace.__getitem__(self, idx)
#     356 if var in self.stat_names:
#     357     return self.get_sampler_stats(var, burn=burn, thin=thin)
# --> 358 raise KeyError("Unknown variable %s" % var)
#
# KeyError: 'Unknown variable like'

# %%
plt.hist(traces['sig1'
               ])
# Out:
# (array([998.,   0.,   1.,   0.,   0.,   0.,   0.,   0.,   0.,   1.]),
#  array([7.41615641e-02, 1.90740016e+04, 3.81479291e+04, 5.72218566e+04,
#         7.62957840e+04, 9.53697115e+04, 1.14443639e+05, 1.33517566e+05,
#         1.52591494e+05, 1.71665421e+05, 1.90739349e+05]),
#  <BarContainer object of 10 artists>)

# %%
betas_1_mean = traces['betas1'].mean(axis=0)
betas_2_mean = traces['betas2'].mean(axis=0)
mus_mean = traces['mus'].mean(axis=0)
betas_1_full = np.concatenate([betas_1_mean, np.zeros(len(dates)-idx)])
betas_2_full = np.concatenate([betas_2_mean, np.zeros(len(dates)-idx)])
mus_full = np.concatenate([mus_mean, np.zeros(len(dates)-idx)])

for idx in range(idx, len(n_pred)):
    betas_1_full[idx] = norm(betas_1_full[idx], )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [90], in <cell line: 1>()
# ----> 1 betas_1_mean = traces['betas1'].mean(axis=0)
#       2 betas_2_mean = traces['betas2'].mean(axis=0)
#       3 mus_mean = traces['mus'].mean(axis=0)
#
# File ~/opt/anaconda3/envs/pymc_env/lib/python3.10/site-packages/pymc/backends/base.py:358, in MultiTrace.__getitem__(self, idx)
#     356 if var in self.stat_names:
#     357     return self.get_sampler_stats(var, burn=burn, thin=thin)
# --> 358 raise KeyError("Unknown variable %s" % var)
#
# KeyError: 'Unknown variable betas1'

# %%
betas_1_full[idx]
# Out:
# 0.0

# %%
plt.hist(traces['mus'][:, 0]);
plt.hist(traces['mus'][:, 5]);
