# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc
rc('text', usetex=True)
plt.style.use('ggplot')
plt.rcParams.update({'axes.labelsize':16})
plt.rcParams.update({'axes.titlesize':16})
plt.rcParams.update({'legend.fontsize':16})
plt.rcParams['xtick.labelsize'] = 16
plt.rcParams['ytick.labelsize'] = 16
plt.rcParams['lines.linewidth'] = 4
import pandas as pd
from sklearn.mixture import GaussianMixture
import os
os.chdir('../code')
from em_alg import EmAlgorithm, StochasticEmAlgorithm, EmBivariateNormal
from scipy.stats import norm, multinomial, multivariate_normal

# %%
df = pd.read_csv('../data/galaxies.csv')
df.columns = ['galaxy', 'velocities']

# %%
plt.figure(figsize=(5, 3))
plt.hist(df['velocities'], edgecolor='black', bins=20)
plt.xlabel('velocity');

# %%
ks = [4,6,8,11,15,20]
x = np.linspace(5, 40, 1000)
fig, axes = plt.subplots(2, 3, figsize=(10, 6))
axes = axes.flatten()
#np.random.seed(1)
for i, k in enumerate(ks):
    em = EmAlgorithm(y=df['velocities'].to_numpy(), pooled_sigma=True, k=k, max_iter=2000, tol=1e-40)
    params = em.fit()
    pdf = np.sum(params['weights'] * norm(params['mus'], params['std']).pdf(np.vstack([x] * k).T), axis=1)
    aic = np.round(2*k - 2*params['loglike'])
    bic = np.round(k * np.log(len(df['velocities'].to_numpy())) - 2*params['loglike'])
    axes[i].plot(x, pdf)
    axes[i].hist(df['velocities'].to_numpy(), density=True, alpha=.8, edgecolor='black')
    axes[i].set_title(f'k = {k}\n BIC = {bic}, AIC = {aic}\n loglike = {np.round(params["loglike"])}')
    axes[i].set_xlabel('velocity')
    gm = GaussianMixture(n_components=k, random_state=0).fit(df['velocities'].to_numpy().reshape(-1, 1))
fig.tight_layout() 
#plt.savefig('../figures/galaxies_1.png', dpi=300)
# Out:
#   7%|████████████                                                                                                                                                                              | 130/1999 [00:00<00:01, 985.66it/s]
#   5%|█████████▎                                                                                                                                                                                | 100/1999 [00:00<00:01, 993.59it/s]
#  12%|█████████████████████▊                                                                                                                                                                    | 235/1999 [00:00<00:01, 991.12it/s]
#  13%|███████████████████████▎                                                                                                                                                                  | 250/1999 [00:00<00:01, 963.19it/s]
#  48%|█████████████████████████████████████████████████████████████████████████████████████████▏                                                                                                | 958/1999 [00:00<00:01, 999.38it/s]
#   8%|█████████████▉                                                                                                                                                                            | 150/1999 [00:00<00:02, 889.72it/s]

# %%
fig, axes = plt.subplots(2, 3, figsize=(10, 6))
axes = axes.flatten()
ks = [3,4,5,6,7,8]
x = np.linspace(5, 40, 1000)
#np.random.seed(1234)
for i, k in enumerate(ks):
    em = EmAlgorithm(y=df['velocities'].to_numpy(), pooled_sigma=False, n_wait=10, k=k, max_iter=10000, tol=1e-6)
    params = em.fit()
    try:
        pdf = np.sum(params['weights'] * norm(params['mus'], params['std']).pdf(np.vstack([x] * k).T), axis=1)
        aic = np.round(2*k - 2*params['loglike'])
        bic = np.round(k * np.log(len(df['velocities'].to_numpy())) - 2*params['loglike'])
        axes[i].plot(x, pdf)
        axes[i].hist(df['velocities'].to_numpy(), density=True, alpha=.8, edgecolor='black')
        axes[i].set_title(f'k = {k}\n BIC = {bic}, AIC = {aic}\n loglike = {np.round(params["loglike"])}')
        axes[i].set_xlabel('velocity')
        gm = GaussianMixture(n_components=k, random_state=0).fit(df['velocities'].to_numpy().reshape(-1, 1))
    except:
        pass
    
fig.tight_layout() 
#plt.savefig('../figures/galaxies_2.png', dpi=300)
# Out:
#   0%|▌                                                                                                                                                                                          | 33/9999 [00:00<00:10, 956.08it/s]
#   0%|                                                                                                                                                                                                     | 0/9999 [00:00<?, ?it/s]/Users/juliette/opt/anaconda3/envs/statmod1/lib/python3.10/site-packages/scipy/stats/_distn_infrastructure.py:2085: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /Users/juliette/opt/anaconda3/envs/statmod1/lib/python3.10/site-packages/scipy/stats/_distn_infrastructure.py:2085: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9999/9999 [00:08<00:00, 1122.17it/s]
#   1%|█▍                                                                                                                                                                                         | 78/9999 [00:00<00:12, 765.98it/s]
#   1%|█▏                                                                                                                                                                                         | 64/9999 [00:00<00:10, 935.73it/s]
#   1%|█▋                                                                                                                                                                                         | 87/9999 [00:00<00:10, 950.44it/s]
#   0%|                                                                                                                                                                                                     | 0/9999 [00:00<?, ?it/s]/Users/juliette/opt/anaconda3/envs/statmod1/lib/python3.10/site-packages/scipy/stats/_distn_infrastructure.py:2085: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /Users/juliette/opt/anaconda3/envs/statmod1/lib/python3.10/site-packages/scipy/stats/_distn_infrastructure.py:2085: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
#  71%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                     | 7077/9999 [00:06<00:02, 1140.95it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [5], line 8
#       6 for i, k in enumerate(ks):
#       7     em = EmAlgorithm(y=df['velocities'].to_numpy(), pooled_sigma=False, n_wait=10, k=k, max_iter=10000, tol=1e-6)
# ----> 8     params = em.fit()
#       9     try:
#      10         pdf = np.sum(params['weights'] * norm(params['mus'], params['std']).pdf(np.vstack([x] * k).T), axis=1)
#
# File ~/Documents/repos/statistical_modeling_1/homework_4/code/em_alg.py:82, in EmAlgorithm.fit(self)
#      80     self.mus[it + 1] = self._update_mus(self.weights_i[it + 1])
#      81 self.std[it + 1] = self._update_sigmas(self.weights_i[it + 1], self.mus[it + 1])
# ---> 82 self.log_likelihoods[it + 1] = self._calculate_log_like(self.mus[it + 1], self.std[it + 1],
#      83                                                         self.weights[it + 1])
#      84 if self._check_convergence(it):
#      85     return {'mus': self.mus[it + 1], 'std': self.std[it + 1], 'weights': self.weights[it + 1],
#      86             'loglike': self.log_likelihoods[it + 1]}
#
# File ~/Documents/repos/statistical_modeling_1/homework_4/code/em_alg.py:63, in EmAlgorithm._calculate_log_like(self, current_mus, current_sigma, current_weights)
#      62 def _calculate_log_like(self, current_mus, current_sigma, current_weights):
# ---> 63     densities = np.sum(current_weights * norm(current_mus, current_sigma).pdf(np.vstack([self.data] * self.k).T),
#      64                        axis=1)
#      65     return np.sum(np.log(densities))
#
# File ~/opt/anaconda3/envs/statmod1/lib/python3.10/site-packages/scipy/stats/_distn_infrastructure.py:859, in rv_generic.__call__(self, *args, **kwds)
#     858 def __call__(self, *args, **kwds):
# --> 859     return self.freeze(*args, **kwds)
#
# File ~/opt/anaconda3/envs/statmod1/lib/python3.10/site-packages/scipy/stats/_distn_infrastructure.py:854, in rv_generic.freeze(self, *args, **kwds)
#     839 """Freeze the distribution for the given arguments.
#     840
#     841 Parameters
#    (...)
#     851
#     852 """
#     853 if isinstance(self, rv_continuous):
# --> 854     return rv_continuous_frozen(self, *args, **kwds)
#     855 else:
#     856     return rv_discrete_frozen(self, *args, **kwds)
#
# File ~/opt/anaconda3/envs/statmod1/lib/python3.10/site-packages/scipy/stats/_distn_infrastructure.py:439, in rv_frozen.__init__(self, dist, *args, **kwds)
#     436 self.kwds = kwds
#     438 # create a new instance
# --> 439 self.dist = dist.__class__(**dist._updated_ctor_param())
#     441 shapes, _, _ = self.dist._parse_args(*args, **kwds)
#     442 self.a, self.b = self.dist._get_support(*shapes)
#
# KeyboardInterrupt:

# %%
ks = [4,6,8,11,15,20]
x = np.linspace(5, 40, 1000)
fig, axes = plt.subplots(2, 3, figsize=(10, 6))
axes = axes.flatten()
#np.random.seed(5050)
for i, k in enumerate(ks):
    try:
        em = StochasticEmAlgorithm(y=df['velocities'].to_numpy(), n_wait=0, pooled_sigma=True, k=k, max_iter=5000, tol=1e-99)
        params = em.fit()
        pdf = np.sum(params['weights'] * norm(params['mus'], params['std']).pdf(np.vstack([x] * k).T), axis=1)
        aic = np.round(2*k - 2*params['loglike'])
        bic = np.round(k * np.log(len(df['velocities'].to_numpy())) - 2*params['loglike'])
        axes[i].plot(x, pdf)
        axes[i].hist(df['velocities'].to_numpy(), density=True, alpha=.8, edgecolor='black')
        axes[i].set_title(f'k = {k}\n BIC = {bic}, AIC = {aic}\n loglike = {np.round(params["loglike"])}')
        axes[i].set_xlabel('velocity')
    except:
        pass
fig.tight_layout() 
#plt.savefig('../figures/galaxies_3.png', dpi=300)

# %%
fig, axes = plt.subplots(2, 3, figsize=(10, 6))
axes = axes.flatten()
ks = [3,4,5,6,7,8]
x = np.linspace(5, 40, 1000)
#i = int(np.random.uniform(0, 1000))
#np.random.seed(i)
#print(i)
for i, k in enumerate(ks):
    em = StochasticEmAlgorithm(y=df['velocities'].to_numpy(), pooled_sigma=False, n_wait=10, k=k, max_iter=10000, tol=1e-5)
    try:
        params = em.fit()
        pdf = np.sum(params['weights'] * norm(params['mus'], params['std']).pdf(np.vstack([x] * k).T), axis=1)
        aic = np.round(2*k - 2*params['loglike'])
        bic = np.round(k * np.log(len(df['velocities'].to_numpy())) - 2*params['loglike'])
        axes[i].plot(x, pdf)
        axes[i].hist(df['velocities'].to_numpy(), density=True, alpha=.8, edgecolor='black')
        axes[i].set_title(f'k = {k}\n BIC = {bic}, AIC = {aic}\n loglike = {np.round(params["loglike"])}')
        axes[i].set_xlabel('velocity')
        gm = GaussianMixture(n_components=k, random_state=0).fit(df['velocities'].to_numpy().reshape(-1, 1))
    except:
        pass
    
fig.tight_layout() 
#plt.savefig('../figures/galaxies_4.png', dpi=300)

# %%
np.random.seed(1111)
df = pd.read_csv('../data/faithful.csv')
data = df[['eruptions', 'waiting']].to_numpy()
#df.columns = ['galaxy', 'velocities']
plt.scatter(df['eruptions'], df['waiting'])

# %%
def calculate_pdf(data, em, n_points=100):
    x = np.linspace(np.min(data[:, 0]), np.max(data[:, 0]), n_points)
    y = np.linspace(np.min(data[:, 1]), np.max(data[:, 1]), n_points)
    xx, yy = np.meshgrid(x, y)
    xx, yy = xx.flatten(), yy.flatten()
    xy = np.vstack([xx, yy]).T
    pdfs = [em.weights[k] * multivariate_normal.pdf(xy, mean=em.means[k, :], cov=em.covs[k]) for k in range(em.k)]
    return x, y, np.sum(pdfs, axis=0)

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 10))
axes = axes.flatten()
ks = [2,3,4,5]
seeds = [417, 2334, 1, 1]
for i, k in enumerate(ks):
    try:
        np.random.seed(seeds[i])
        em = EmBivariateNormal(data, k=k, max_iter=2000)
        em.fit()
        x, y, density = calculate_pdf(data, em)
        density = density.reshape(100, 100)

        axes[i].contourf(x, y, density, cmap='coolwarm', levels=1000, alpha=.9)
        axes[i].scatter(df['eruptions'], df['waiting'], color='black')
        axes[i].set_xlabel('eruptions')
        axes[i].set_ylabel('density')

        aic = np.round(2*em.k - 2*em.log_likes[-1])
        bic = np.round(em.k * np.log(len(data) - 2*em.log_likes[-1]))
        axes[i].set_title(f'k = {em.k}\n BIC = {bic}, AIC = {aic}\n loglike = {np.round(params["loglike"])}')
    except:
        pass
    #plt.savefig('../figures/bivariate.png', dpi=300, bbox_inches='tight')
# Out:
#   0%|▋                                                                                                                                                                                          | 8/2000 [00:00<00:01, 1251.42it/s]
# [[ 4.28967358 79.9682555 ]
#  [ 2.03640157 54.47864835]]
#   1%|█▍                                                                                                                                                                                        | 15/2000 [00:00<00:01, 1658.18it/s]
# [[ 2.03423868 54.45709161]
#  [ 4.28625525 83.55472666]
#  [ 4.28930447 76.1212969 ]]
#   0%|                                                                                                                                                                                           | 1/2000 [00:00<00:01, 1055.70it/s]
#   0%|                                                                                                                                                                                            | 1/2000 [00:00<00:04, 458.04it/s]

# %%
x, y, density = calculate_pdf(data, em)
density = density.reshape(100, 100)

plt.contourf(x, y, density, cmap='coolwarm', levels=1000, alpha=.9)
plt.scatter(df['eruptions'], df['waiting'], color='black')
plt.xlabel('eruptions')
plt.ylabel('density')

aic = np.round(2*em.k - 2*em.log_likes[-1])
bic = np.round(em.k * np.log(len(data) - 2*em.log_likes[-1]))
plt.title(f'k = {em.k}\n BIC = {bic}, AIC = {aic}\n loglike = {np.round(params["loglike"])}')
plt.savefig('../figures/bivariate.png', dpi=300, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [28], line 1
# ----> 1 x, y, density = calculate_pdf(data, em)
#       2 density = density.reshape(100, 100)
#       4 plt.contourf(x, y, density, cmap='coolwarm', levels=1000, alpha=.9)
#
# Cell In [7], line 7, in calculate_pdf(data, em, n_points)
#       5 xx, yy = xx.flatten(), yy.flatten()
#       6 xy = np.vstack([xx, yy]).T
# ----> 7 pdfs = [em.weights[k] * multivariate_normal.pdf(xy, mean=em.means[k, :], cov=em.covs[k]) for k in range(em.k)]
#       8 return x, y, np.sum(pdfs, axis=0)
#
# Cell In [7], line 7, in <listcomp>(.0)
#       5 xx, yy = xx.flatten(), yy.flatten()
#       6 xy = np.vstack([xx, yy]).T
# ----> 7 pdfs = [em.weights[k] * multivariate_normal.pdf(xy, mean=em.means[k, :], cov=em.covs[k]) for k in range(em.k)]
#       8 return x, y, np.sum(pdfs, axis=0)
#
# File ~/opt/anaconda3/envs/statmod1/lib/python3.10/site-packages/scipy/stats/_multivariate.py:541, in multivariate_normal_gen.pdf(self, x, mean, cov, allow_singular)
#     539 dim, mean, cov = self._process_parameters(None, mean, cov)
#     540 x = self._process_quantiles(x, dim)
# --> 541 psd = _PSD(cov, allow_singular=allow_singular)
#     542 out = np.exp(self._logpdf(x, mean, psd.U, psd.log_pdet, psd.rank))
#     543 if allow_singular and (psd.rank < dim):
#
# File ~/opt/anaconda3/envs/statmod1/lib/python3.10/site-packages/scipy/stats/_multivariate.py:157, in _PSD.__init__(self, M, cond, rcond, lower, check_finite, allow_singular)
#     152 def __init__(self, M, cond=None, rcond=None, lower=True,
#     153              check_finite=True, allow_singular=True):
#     154     # Compute the symmetric eigendecomposition.
#     155     # Note that eigh takes care of array conversion, chkfinite,
#     156     # and assertion that the matrix is square.
# --> 157     s, u = scipy.linalg.eigh(M, lower=lower, check_finite=check_finite)
#     159     eps = _eigvalsh_to_eps(s, cond, rcond)
#     160     if np.min(s) < -eps:
#
# File ~/opt/anaconda3/envs/statmod1/lib/python3.10/site-packages/scipy/linalg/_decomp.py:447, in eigh(a, b, lower, eigvals_only, overwrite_a, overwrite_b, turbo, eigvals, type, check_finite, subset_by_index, subset_by_value, driver)
#     443 if driver not in drv_str:
#     444     raise ValueError('"{}" is unknown. Possible values are "None", "{}".'
#     445                      ''.format(driver, '", "'.join(drv_str[1:])))
# --> 447 a1 = _asarray_validated(a, check_finite=check_finite)
#     448 if len(a1.shape) != 2 or a1.shape[0] != a1.shape[1]:
#     449     raise ValueError('expected square "a" matrix')
#
# File ~/opt/anaconda3/envs/statmod1/lib/python3.10/site-packages/scipy/_lib/_util.py:287, in _asarray_validated(a, check_finite, sparse_ok, objects_ok, mask_ok, as_inexact)
#     285         raise ValueError('masked arrays are not supported')
#     286 toarray = np.asarray_chkfinite if check_finite else np.asarray
# --> 287 a = toarray(a)
#     288 if not objects_ok:
#     289     if a.dtype is np.dtype('O'):
#
# File ~/opt/anaconda3/envs/statmod1/lib/python3.10/site-packages/numpy/lib/function_base.py:627, in asarray_chkfinite(a, dtype, order)
#     625 a = asarray(a, dtype=dtype, order=order)
#     626 if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 627     raise ValueError(
#     628         "array must not contain infs or NaNs")
#     629 return a
#
# ValueError: array must not contain infs or NaNs

# %%
# Out:
#   2%|██▊                                                                                                                                                                                        | 30/2000 [00:00<00:02, 900.57it/s]
#   0%|                                                                                                                                                                                            | 1/2000 [00:00<00:07, 269.04it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [19], line 5
#       3 for i, k in enumerate(ks):
#       4     em = EmBivariateNormal(data, k=k, max_iter=2000)
# ----> 5     em.fit()
#
# File ~/Documents/repos/statistical_modeling_1/homework_4/code/em_alg.py:139, in EmBivariateNormal.fit(self)
#     137 def fit(self):
#     138     for it in tqdm(range(self.max_iter)):
# --> 139         self.W = self._update_W(self.weights, self.means, self.covs)
#     140         self.log_likes.append(self._calculate_log_likes(self.weights, self.means, self.covs))
#     141         if it > 10:
#
# File ~/Documents/repos/statistical_modeling_1/homework_4/code/em_alg.py:164, in EmBivariateNormal._update_W(self, weights, means, covs)
#     162 W_un_normalized = np.zeros((self.data.shape[0], self.k))
#     163 for k in range(self.k):
# --> 164     W_un_normalized[:, k] = weights[k] * multivariate_normal.pdf(self.data, mean=means[k], cov=covs[k],
#     165                                                                  allow_singular=True)
#     166 W_normalized = (W_un_normalized.T / W_un_normalized.sum(axis=1)).T
#     167 return W_normalized
#
# File ~/opt/anaconda3/envs/statmod1/lib/python3.10/site-packages/scipy/stats/_multivariate.py:541, in multivariate_normal_gen.pdf(self, x, mean, cov, allow_singular)
#     539 dim, mean, cov = self._process_parameters(None, mean, cov)
#     540 x = self._process_quantiles(x, dim)
# --> 541 psd = _PSD(cov, allow_singular=allow_singular)
#     542 out = np.exp(self._logpdf(x, mean, psd.U, psd.log_pdet, psd.rank))
#     543 if allow_singular and (psd.rank < dim):
#
# File ~/opt/anaconda3/envs/statmod1/lib/python3.10/site-packages/scipy/stats/_multivariate.py:157, in _PSD.__init__(self, M, cond, rcond, lower, check_finite, allow_singular)
#     152 def __init__(self, M, cond=None, rcond=None, lower=True,
#     153              check_finite=True, allow_singular=True):
#     154     # Compute the symmetric eigendecomposition.
#     155     # Note that eigh takes care of array conversion, chkfinite,
#     156     # and assertion that the matrix is square.
# --> 157     s, u = scipy.linalg.eigh(M, lower=lower, check_finite=check_finite)
#     159     eps = _eigvalsh_to_eps(s, cond, rcond)
#     160     if np.min(s) < -eps:
#
# File ~/opt/anaconda3/envs/statmod1/lib/python3.10/site-packages/scipy/linalg/_decomp.py:447, in eigh(a, b, lower, eigvals_only, overwrite_a, overwrite_b, turbo, eigvals, type, check_finite, subset_by_index, subset_by_value, driver)
#     443 if driver not in drv_str:
#     444     raise ValueError('"{}" is unknown. Possible values are "None", "{}".'
#     445                      ''.format(driver, '", "'.join(drv_str[1:])))
# --> 447 a1 = _asarray_validated(a, check_finite=check_finite)
#     448 if len(a1.shape) != 2 or a1.shape[0] != a1.shape[1]:
#     449     raise ValueError('expected square "a" matrix')
#
# File ~/opt/anaconda3/envs/statmod1/lib/python3.10/site-packages/scipy/_lib/_util.py:287, in _asarray_validated(a, check_finite, sparse_ok, objects_ok, mask_ok, as_inexact)
#     285         raise ValueError('masked arrays are not supported')
#     286 toarray = np.asarray_chkfinite if check_finite else np.asarray
# --> 287 a = toarray(a)
#     288 if not objects_ok:
#     289     if a.dtype is np.dtype('O'):
#
# File ~/opt/anaconda3/envs/statmod1/lib/python3.10/site-packages/numpy/lib/function_base.py:627, in asarray_chkfinite(a, dtype, order)
#     625 a = asarray(a, dtype=dtype, order=order)
#     626 if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 627     raise ValueError(
#     628         "array must not contain infs or NaNs")
#     629 return a
#
# ValueError: array must not contain infs or NaNs

# %%
data.shape

# %%
10000

# %%
100 * 100

# %%
def d():
    draw = np.random.choice([0, 1], p=[.99, .01])
    if draw == 1:
        return draw
    else:
        return d()

# %%
d()

# %%
multivariate_normal(np.array([1]), np.array([1])).rvs()

# %%
means = np.ones((2))
covs = np.ones((2, 2))

# %%
np.repeat(np.diag(np.ones(2)), 5, axis=1).shape

# %%
np.diag(np.ones(2)).shape

# %%
n = 2
a = np.broadcast_to(np.identity(n), (100, 5, n, n)).reshape(100, n, n, 5)
a[0] = np.ones((2, 2, 5))

# %%
[np.random.choice(3,4)]

# %%
np.matmul(a, a.T)

# %%
a.shape

# %%
a.T.shape

# %%
a = np.ones((5, 2, 3, 4))

# %%
a[0] = np.ones((2, 3, 4))

# %%
a
